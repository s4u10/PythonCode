# %%
# Path - dataset1
path_dataset1 = "/FileStore/tables/country_vaccinations.csv"
 
# Path - RDD
path_rdd = "/FileStore/tables/arquivo_rdd.txt"

# %%
# Leitura de Dataframe
 
## Opção 1
df1 = spark.read.format("csv").option("header","true").option("inferSchema","false").load(path_dataset1)
 
## Opção 2
# df1 = spark.read.csv(path_dataset1)
# df1 = spark.read.option("header","true").option("inferSchema","true").csv(path_dataset1)
 
## Exibindo dataframe
df1.show(2)
#df1.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# Afghanistan|     AFG|2021-02-22|               0.0|              0.0|                   null|                  null|              null|                           0.0|                          0.0|                               null|                          null|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-02-23|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# only showing top 2 rows
#
# </div>

# %%
df1.take(1)[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Row(country='Afghanistan', iso_code='AFG', date='2021-02-22', total_vaccinations='0.0', people_vaccinated='0.0', people_fully_vaccinated=None, daily_vaccinations_raw=None, daily_vaccinations=None, total_vaccinations_per_hundred='0.0', people_vaccinated_per_hundred='0.0', people_fully_vaccinated_per_hundred=None, daily_vaccinations_per_million=None, vaccines='Johnson&amp;Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing', source_name='World Health Organization', source_website='https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9')</div>

# %%
df1.write.format("parquet").mode("overwrite").save("/FileStore/tables/RAW_ZONE_PARQUET/")

# %%
df1.take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>[Row(country='Afghanistan', iso_code='AFG', date='2021-02-22', total_vaccinations='0.0', people_vaccinated='0.0', people_fully_vaccinated=None, daily_vaccinations_raw=None, daily_vaccinations=None, total_vaccinations_per_hundred='0.0', people_vaccinated_per_hundred='0.0', people_fully_vaccinated_per_hundred=None, daily_vaccinations_per_million=None, vaccines='Johnson&amp;Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing', source_name='World Health Organization', source_website='https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9'),
#  Row(country='Afghanistan', iso_code='AFG', date='2021-02-23', total_vaccinations=None, people_vaccinated=None, people_fully_vaccinated=None, daily_vaccinations_raw=None, daily_vaccinations='1367.0', total_vaccinations_per_hundred=None, people_vaccinated_per_hundred=None, people_fully_vaccinated_per_hundred=None, daily_vaccinations_per_million='34.0', vaccines='Johnson&amp;Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing', source_name='World Health Organization', source_website='https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9'),
#  Row(country='Afghanistan', iso_code='AFG', date='2021-02-24', total_vaccinations=None, people_vaccinated=None, people_fully_vaccinated=None, daily_vaccinations_raw=None, daily_vaccinations='1367.0', total_vaccinations_per_hundred=None, people_vaccinated_per_hundred=None, people_fully_vaccinated_per_hundred=None, daily_vaccinations_per_million='34.0', vaccines='Johnson&amp;Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing', source_name='World Health Organization', source_website='https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9')]</div>

# %%
## Outras formas de leitura de arquivos com PySpark
 
path = "/../../arquivoXPTO"
 
# Criando um dataframe a partir de um JSON
dataframe = spark.read.json(path)
 
# Criando um dataframe a partir de um ORC
dataframe = spark.read.orc(path)
 
# Criando um dataframe a partir de um PARQUET
dataframe = spark.read.parquet(path)

# %%
## Imprimindo tipos de campos
 
df1.dtypes
#df1.printSchema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>[('country', 'string'),
#  ('iso_code', 'string'),
#  ('date', 'string'),
#  ('total_vaccinations', 'string'),
#  ('people_vaccinated', 'string'),
#  ('people_fully_vaccinated', 'string'),
#  ('daily_vaccinations_raw', 'string'),
#  ('daily_vaccinations', 'string'),
#  ('total_vaccinations_per_hundred', 'string'),
#  ('people_vaccinated_per_hundred', 'string'),
#  ('people_fully_vaccinated_per_hundred', 'string'),
#  ('daily_vaccinations_per_million', 'string'),
#  ('vaccines', 'string'),
#  ('source_name', 'string'),
#  ('source_website', 'string')]</div>

# %%
# Leitura de um RDD
 
rdd = sc.textFile(path_rdd)
#rdd.show() = Errado, não é possível exibir um SHOW() de um RDD, somente um Dataframe
rdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>['{\\rtf1\\ansi\\ansicpg1252\\cocoartf2578',
#  '\\cocoatextscaling0\\cocoaplatform0{\\fonttbl}',
#  '{\\colortbl;\\red255\\green255\\blue255;}',
#  '{\\*\\expandedcolortbl;;}',
#  '\\paperw11900\\paperh16840\\margl1440\\margr1440\\vieww11520\\viewh8400\\viewkind0',
#  '}']</div>

# %%
dfff = spark.read.format("csv").load(path_rdd)
display(dfff)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th></tr></thead><tbody><tr><td>{\rtf1\ansi\ansicpg1252\cocoartf2578</td></tr><tr><td>\cocoatextscaling0\cocoaplatform0{\fonttbl}</td></tr><tr><td>{\colortbl;\red255\green255\blue255;}</td></tr><tr><td>{\*\expandedcolortbl;;}</td></tr><tr><td>\paperw11900\paperh16840\margl1440\margr1440\vieww11520\viewh8400\viewkind0</td></tr><tr><td>}</td></tr></tbody></table></div>

# %%
# Criando uma tabela temporária
nome_tabela_temporiaria = "tempTableTerere"
df1.createOrReplaceTempView(nome_tabela_temporiaria)

# %%
nome_tabela_temporiaria = "tempTableDataFrame1"
df1.createOrReplaceTempView(nome_tabela_temporiaria)

# %%
# Lendo a tabela temporaria opcao 1
spark.read.table(nome_tabela_temporiaria).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# Afghanistan|     AFG|2021-02-22|               0.0|              0.0|                   null|                  null|              null|                           0.0|                          0.0|                               null|                          null|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-02-23|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-02-24|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-02-25|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-02-26|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-02-27|              null|             null|                   null|                  null|            1367.0|                          null|                         null|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-02-28|            8200.0|           8200.0|                   null|                  null|            1367.0|                          0.02|                         0.02|                               null|                          34.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-01|              null|             null|                   null|                  null|            1580.0|                          null|                         null|                               null|                          40.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-02|              null|             null|                   null|                  null|            1794.0|                          null|                         null|                               null|                          45.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-03|              null|             null|                   null|                  null|            2008.0|                          null|                         null|                               null|                          50.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-04|              null|             null|                   null|                  null|            2221.0|                          null|                         null|                               null|                          56.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-05|              null|             null|                   null|                  null|            2435.0|                          null|                         null|                               null|                          61.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-06|              null|             null|                   null|                  null|            2649.0|                          null|                         null|                               null|                          66.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-07|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-08|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-09|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-10|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-11|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-12|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# Afghanistan|     AFG|2021-03-13|              null|             null|                   null|                  null|            2862.0|                          null|                         null|                               null|                          72.0|Johnson&amp;Johnson, ...|World Health Orga...|https://app.power...|
# +-----------+--------+----------+------------------+-----------------

# %%
spark.sql("SELECT count(*) tt, country FROM tempTableTerere Group By country").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+--------------------+
#  tt|             country|
# +---+--------------------+
# 109|                Chad|
# 233|            Anguilla|
# 231|              Guyana|
# 167|            Djibouti|
# 196|                Fiji|
# 210|                Iraq|
# 278|             Germany|
# 155|             Comoros|
# 207|         Afghanistan|
# 232|            Cambodia|
# 277|              France|
# 277|              Greece|
# 127|British Virgin Is...|
# 226|            Dominica|
# 240|             Algeria|
# 199|   Equatorial Guinea|
# 276|           Argentina|
# 210|              Angola|
# 277|             Belgium|
# 253|             Ecuador|
# +---+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# Visualização do Databricks
display(spark.sql("SELECT * FROM tempTableDataFrame1"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>iso_code</th><th>date</th><th>total_vaccinations</th><th>people_vaccinated</th><th>people_fully_vaccinated</th><th>daily_vaccinations_raw</th><th>daily_vaccinations</th><th>total_vaccinations_per_hundred</th><th>people_vaccinated_per_hundred</th><th>people_fully_vaccinated_per_hundred</th><th>daily_vaccinations_per_million</th><th>vaccines</th><th>source_name</th><th>source_website</th></tr></thead><tbody><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-22</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-23</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-24</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-25</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-26</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-27</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-28</td><td>8200.0</td><td>8200.0</td><td>null</td><td>null</td><td>1367.0</td><td>0.02</td><td>0.02</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-01</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1580.0</td><td>null</td><td>null</td><td>null</td><td>40.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>W ...

# %%
dfterere = spark.sql("SELECT count(*) tt, country FROM tempTableTerere Group By country")
dfterere.show(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+--------+
#  tt| country|
# +---+--------+
# 109|    Chad|
# 233|Anguilla|
# 231|  Guyana|
# +---+--------+
# only showing top 3 rows
#
# </div>

# %%
dfterere = spark.sql("SELECT count(*) tt, country FROM tempTableTerere Group By country")
dfterere.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>[('tt', 'bigint'), ('country', 'string')]</div>

# %%
# Visualização do Databricks
display(spark.sql("SELECT * FROM tempTableDataFrame1"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>iso_code</th><th>date</th><th>total_vaccinations</th><th>people_vaccinated</th><th>people_fully_vaccinated</th><th>daily_vaccinations_raw</th><th>daily_vaccinations</th><th>total_vaccinations_per_hundred</th><th>people_vaccinated_per_hundred</th><th>people_fully_vaccinated_per_hundred</th><th>daily_vaccinations_per_million</th><th>vaccines</th><th>source_name</th><th>source_website</th></tr></thead><tbody><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-22</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-23</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-24</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-25</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-26</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-27</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-28</td><td>8200.0</td><td>8200.0</td><td>null</td><td>null</td><td>1367.0</td><td>0.02</td><td>0.02</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-01</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1580.0</td><td>null</td><td>null</td><td>null</td><td>40.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>W ...

# %%
nome_tabela_temporiaria = "tempTableDataFrame1"
df1.createOrReplaceTempView(nome_tabela_temporiaria)

# %%
# Scala
#import org.apache.spark.sql.functions._
 
# Python
from pyspark.sql.functions import col, column

# Usando function col ou column
#df1.select(col("country"), col("date"), column("iso_code")).show()
 
# Usando function col ou column
df1.selectExpr("country","date","iso_code").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+----------+--------+
#     country|      date|iso_code|
# +-----------+----------+--------+
# Afghanistan|2021-02-22|     AFG|
# Afghanistan|2021-02-23|     AFG|
# Afghanistan|2021-02-24|     AFG|
# Afghanistan|2021-02-25|     AFG|
# Afghanistan|2021-02-26|     AFG|
# Afghanistan|2021-02-27|     AFG|
# Afghanistan|2021-02-28|     AFG|
# Afghanistan|2021-03-01|     AFG|
# Afghanistan|2021-03-02|     AFG|
# Afghanistan|2021-03-03|     AFG|
# Afghanistan|2021-03-04|     AFG|
# Afghanistan|2021-03-05|     AFG|
# Afghanistan|2021-03-06|     AFG|
# Afghanistan|2021-03-07|     AFG|
# Afghanistan|2021-03-08|     AFG|
# Afghanistan|2021-03-09|     AFG|
# Afghanistan|2021-03-10|     AFG|
# Afghanistan|2021-03-11|     AFG|
# Afghanistan|2021-03-12|     AFG|
# Afghanistan|2021-03-13|     AFG|
# +-----------+----------+--------+
# only showing top 20 rows
#
# </div>

# %%
# Scala import
# org.apache.spark.sql.types._
 
# Criando um Schema manualmente no PySpark
from pyspark.sql.types import *
 
dataframe_ficticio = StructType([
                      StructField("col_String_1", StringType()),
                      StructField("col_Integer_2", IntegerType()),
                      StructField("col_Decimal_3", DecimalType())
                              ])
dataframe_ficticio
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>StructType(List(StructField(col_String_1,StringType,true),StructField(col_Integer_2,IntegerType,true),StructField(col_Decimal_3,DecimalType(10,0),true)))</div>

# %%
# Função para gerar Schema (campos/colunas/nomes de colunas)
 
'''
# Scala
 
org.apache.spark.sql.types._
 
def getSchema(fields : Array[StructField]) : StructType = {
  new StructType(fields)
}
'''
 
# PySpark
def getSchema(fields):
  return StructType(fields)
  
schema = getSchema([StructField("coluna1", StringType()), StructField("coluna2", StringType()), StructField("coluna3", StringType())])

# %%
# Gravando um novo CSV
 
path_destino="/FileStore/tables/CSV/"
nome_arquivo="arquivo.csv"
path_geral= path_destino + nome_arquivo
df1.write.format("csv").mode("overwrite").option("sep", "\t").save(path_geral)

# %%
# Gravando um novo JSON
 
path_destino="/FileStore/tables/JSON/"
nome_arquivo="arquivo.json"
path_geral= path_destino + nome_arquivo
df1.write.format("json").mode("overwrite").save(path_geral)

# %%
# Gravando um novo PARQUET
 
path_destino="/FileStore/tables/PARQUET/"
nome_arquivo="arquivo.parquet"
path_geral= path_destino + nome_arquivo
df1.write.format("parquet").mode("overwrite").save(path_geral)

# %%
# Gravando um novo ORC
 
path_destino="/FileStore/tables/ORC/"
nome_arquivo="arquivo.orc"
path_geral= path_destino + nome_arquivo
df1.write.format("orc").mode("overwrite").save(path_geral)

# %%
# Outros tipos de SELECT
 
#Diferentes formas de selecionar uma coluna
 
from pyspark.sql.functions import *
 
df1.select("country").show(5)
df1.select('country').show(5)
#df1.select(col("country")).show(5)
#df1.select(column("country")).show(5)
df1.select(expr("country")).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# +-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+
#     country|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# </div>

# %%
# Define uma nova coluna com um valor constante
df2 = df1.withColumn("nova_coluna", lit(1))
display(df1)
display(df2)
 
# Adicionar coluna
teste = expr("total_vaccinations < 40")
df1.select("country", "total_vaccinations").withColumn("teste", teste).show(5)
 
 
# Renomear uma coluna
df1.select(expr("total_vaccinations as total_de_vacinados")).show(5)
df1.select(col("country").alias("pais")).show(5)
df1.select("country").withColumnRenamed("country", "pais").show(5)
 
# Remover uma coluna
df3 = df1.drop("country")
df3.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+------------------+-----+
#     country|total_vaccinations|teste|
# +-----------+------------------+-----+
# Afghanistan|               0.0| true|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# Afghanistan|              null| null|
# +-----------+------------------+-----+
# only showing top 5 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------------------+
# total_de_vacinados|
# +------------------+
#                0.0|
#               null|
#               null|
#               null|
#               null|
# +------------------+
# only showing top 5 rows
#
# +-----------+
#        pais|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+
#        pais|
# +-----------+
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 5 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>['iso_code',
#  'date',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'daily_vaccinations_raw',
#  'daily_vaccinations',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'daily_vaccinations_per_million',
#  'vaccines',
#  'source_name',
#  'source_website']</div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>iso_code</th><th>date</th><th>total_vaccinations</th><th>people_vaccinated</th><th>people_fully_vaccinated</th><th>daily_vaccinations_raw</th><th>daily_vaccinations</th><th>total_vaccinations_per_hundred</th><th>people_vaccinated_per_hundred</th><th>people_fully_vaccinated_per_hundred</th><th>daily_vaccinations_per_million</th><th>vaccines</th><th>source_name</th><th>source_website</th></tr></thead><tbody><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-22</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-23</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-24</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-25</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-26</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-27</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-28</td><td>8200.0</td><td>8200.0</td><td>null</td><td>null</td><td>1367.0</td><td>0.02</td><td>0.02</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-01</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1580.0</td><td>null</td><td>null</td><td>null</td><td>40.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>W ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>iso_code</th><th>date</th><th>total_vaccinations</th><th>people_vaccinated</th><th>people_fully_vaccinated</th><th>daily_vaccinations_raw</th><th>daily_vaccinations</th><th>total_vaccinations_per_hundred</th><th>people_vaccinated_per_hundred</th><th>people_fully_vaccinated_per_hundred</th><th>daily_vaccinations_per_million</th><th>vaccines</th><th>source_name</th><th>source_website</th><th>nova_coluna</th></tr></thead><tbody><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-22</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>0.0</td><td>0.0</td><td>null</td><td>null</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-23</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-24</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-25</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-26</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-27</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1367.0</td><td>null</td><td>null</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-02-28</td><td>8200.0</td><td>8200.0</td><td>null</td><td>null</td><td>1367.0</td><td>0.02</td><td>0.02</td><td>null</td><td>34.0</td><td>Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing</td><td>World Health Organization</td><td>https://app.powerbi.com/view?r=eyJrIjoiYTkyM2VmMDUtNDJjOC00YjU2LWI3Y2MtNTRhMWY4YzU0YTRlIiwidCI6ImY2MTBjMGI3LWJkMjQtNGIzOS04MTBiLTNkYzI4MGFmYjU5MCIsImMiOjh9</td><td>1</td></tr><tr><td>Afghanistan</td><td>AFG</td><td>2021-03-01</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1580.0</td><td>null</td><td>null</td><td>null</td><td>40.0 ...

# %%
# Filtrando dados e ordenando
# where() é um alias para filter().
 
# Seleciona apenas os primeiros registros da coluna "total_vaccinations"
df1.filter(df1.total_vaccinations > 55).orderBy(df1.total_vaccinations).show(2)
 
# Filtra por país igual Argentina
df1.select(df1.total_vaccinations, df1.country).filter(df1.country == "Argentina").show(5)
 
# Filtra por país diferente Argentina
df1.select(df1.total_vaccinations, df1.country).where(df1.country != "Argentina").show(5) # python type
 
# Mostra valores únicos
df1.select("country").distinct().show()
 
# Especificando vários filtros em comando separados
filtro_vacinas = df1.total_vaccinations < 100
filtro_pais = df1.country.contains("Argentina")
df1.select(df1.total_vaccinations, df1.country, df1.vaccines).where(df1.vaccines.isin("Sputnik V", "Sinovac")).filter(filtro_vacinas).show(5)
df1.select(df1.total_vaccinations, df1.country, df1.vaccines).where(df1.vaccines.isin("Sputnik V", "Sinovac")).filter(filtro_vacinas).withColumn("filtro_pais", filtro_pais).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     country|iso_code|      date|total_vaccinations|people_vaccinated|people_fully_vaccinated|daily_vaccinations_raw|daily_vaccinations|total_vaccinations_per_hundred|people_vaccinated_per_hundred|people_fully_vaccinated_per_hundred|daily_vaccinations_per_million|            vaccines|         source_name|      source_website|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
#     Bahamas|     BHS|2021-04-07|           10000.0|          10000.0|                   null|                  null|             300.0|                          2.52|                         2.52|                               null|                         756.0|Johnson&amp;Johnson, ...|Pan American Heal...|https://ais.paho....|
# Philippines|     PHL|2021-03-04|           10000.0|          10000.0|                   null|                  null|            2500.0|                          0.01|                         0.01|                               null|                          23.0|Johnson&amp;Johnson, ...|Department of Hea...|https://news.abs-...|
# +-----------+--------+----------+------------------+-----------------+-----------------------+----------------------+------------------+------------------------------+-----------------------------+-----------------------------------+------------------------------+--------------------+--------------------+--------------------+
# only showing top 2 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------------------+---------+
# total_vaccinations|  country|
# +------------------+---------+
#              700.0|Argentina|
#               null|Argentina|
#            32013.0|Argentina|
#               null|Argentina|
#               null|Argentina|
# +------------------+---------+
# only showing top 5 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------------------+-----------+
# total_vaccinations|    country|
# +------------------+-----------+
#                0.0|Afghanistan|
#               null|Afghanistan|
#               null|Afghanistan|
#               null|Afghanistan|
#               null|Afghanistan|
# +------------------+-----------+
# only showing top 5 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-------------------+
#             country|
# +-------------------+
#            Anguilla|
#         Afghanistan|
#             Algeria|
#           Argentina|
#              Angola|
#             Belgium|
#             Albania|
#               Benin|
#             Bahamas|
#             Belarus|
#             Andorra|
#          Bangladesh|
#            Barbados|
#               Aruba|
#          Azerbaijan|
#             Armenia|
#              Belize|
# Antigua and Barbuda|
#           Australia|
#             Austria|
# +-------------------+
# only showing top 20 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------------------+-------+--------+
# total_vaccinations|country|vaccines|
# +------------------+-------+--------+
# +------------------+-------+--------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+------------------+-------+--------+-----------+
# total_vaccinations|country|vaccines|filtro_pais|
# +------------------+-------+--------+-----------+
# +------------------+-------+--------+-----------+
#
# </div>

# %%
"""#######################################################################################################################
Convertendo dados
#######################################################################################################################"""
 
df5 = df1.withColumn("PAIS", col("country").cast("string").alias("PAIS"))
df5.select(df5.PAIS).show(2)
 
"""#######################################################################################################################
Trabalhando com funções
#######################################################################################################################"""
 
# Usando funções
df1.select(upper(df1.country)).show(3)
df1.select(lower(df1.country)).show(4)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----------+
#        PAIS|
# +-----------+
# Afghanistan|
# Afghanistan|
# +-----------+
# only showing top 2 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+--------------+
# upper(country)|
# +--------------+
#    AFGHANISTAN|
#    AFGHANISTAN|
#    AFGHANISTAN|
# +--------------+
# only showing top 3 rows
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+--------------+
# lower(country)|
# +--------------+
#    afghanistan|
#    afghanistan|
#    afghanistan|
#    afghanistan|
# +--------------+
# only showing top 4 rows
#
# </div>

# %%
# Criando um dataframe genérico
 
d = [{'name': 'Alice', 'age': 1}]
df_A = spark.createDataFrame(d)
df_A.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+---+-----+
# age| name|
# +---+-----+
#   1|Alice|
# +---+-----+
#
# </div>

# %%
rdd1 = [{"nome": "Marco","idade": 33,"status": 'true'},
{"nome": "Antonio","idade":33,"status": 'true'},
{"nome":"Pereira","idade":33,"status": 'true'},
{"nome":"Helena","idade":30,"status": 'true'},
{"nome":"Fernando","idade":35,"status": 'true'},
{"nome":"Carlos","idade":28,"status": 'true'},
{"nome":"Lisa","idade":26,"status": 'true'},
{"nome":"Candido","idade":75,"status": 'false'},
{"nome":"Vasco","idade":62,"status": 'true'}
]
dff1 = spark.createDataFrame(rdd1)
dff1.show()
 
 
rdd2 = [
{"nome":"Marco","PaisOrigem":"Brasil"},
{"nome":"Helena","PaisOrigem":"Brasil"},
{"nome":"Gabriel","PaisOrigem":"Brasil"},
{"nome":"Vasco","PaisOrigem":"Portugal"},
{"nome":"Medhi","PaisOrigem":"Marocco"}]
 
dff2 = spark.createDataFrame(rdd2)
dff2.show()
 
'''
join_type = "inner"
 
+------+-----+------+------+----------+
|  nome|idade|status|  nome|PaisOrigem|
+------+-----+------+------+----------+
| Vasco|   62|  true| Vasco|  Portugal|
| Marco|   33|  true| Marco|    Brasil|
|Helena|   30|  true|Helena|    Brasil|
+------+-----+------+------+----------+
'''
 
'''val join_type = "left_semi"
 
+------+-----+------+
|  nome|idade|status|
+------+-----+------+
| Vasco|   62|  true|
| Marco|   33|  true|
|Helena|   30|  true|
+------+-----+------+
'''
 
'''val join_type = "right_outer"
 
+------+-----+------+-------+----------+
|  nome|idade|status|   nome|PaisOrigem|
+------+-----+------+-------+----------+
| Vasco|   62|  true|  Vasco|  Portugal|
| Marco|   33|  true|  Marco|    Brasil|
|  null| null|  null|Gabriel|    Brasil|
|Helena|   30|  true| Helena|    Brasil|
|  null| null|  null|  Medhi|   Marocco|
+------+-----+------+-------+----------+
'''
 
'''val join_type = "left_outer"
 
+--------+-----+------+------+----------+
|    nome|idade|status|  nome|PaisOrigem|
+--------+-----+------+------+----------+
| Antonio|   33|  true|  null|      null|
|   Vasco|   62|  true| Vasco|  Portugal|
|   Marco|   33|  true| Marco|    Brasil|
| Pereira|   33|  true|  null|      null|
|  Carlos|   28|  true|  null|      null|
|Fernando|   35|  true|  null|      null|
| Candido|   75| false|  null|      null|
|  Helena|   30|  true|Helena|    Brasil|
|    Lisa|   26|  true|  null|      null|
+--------+-----+------+------+----------+
'''
 
'''join_type = "full_outer"
 
+--------+-----+------+-------+----------+
|    nome|idade|status|   nome|PaisOrigem|
+--------+-----+------+-------+----------+
| Antonio|   33|  true|   null|      null|
|   Vasco|   62|  true|  Vasco|  Portugal|
|   Marco|   33|  true|  Marco|    Brasil|
| Pereira|   33|  true|   null|      null|
|  Carlos|   28|  true|   null|      null|
|    null| null|  null|Gabriel|    Brasil|
|Fernando|   35|  true|   null|      null|
| Candido|   75| false|   null|      null|
|  Helena|   30|  true| Helena|    Brasil|
|    Lisa|   26|  true|   null|      null|
|    null| null|  null|  Medhi|   Marocco|
+--------+-----+------+-------+----------+
'''
 
'''join_type = "left_anti"
 
+--------+-----+------+
|    nome|idade|status|
+--------+-----+------+
| Antonio|   33|  true|
| Pereira|   33|  true|
|  Carlos|   28|  true|
|Fernando|   35|  true|
| Candido|   75| false|
|    Lisa|   26|  true|
+--------+-----+------+
'''
 
join_type = "inner"
join_condition = dff1.nome == dff2.nome
df3 = dff1.join(dff2, join_condition, join_type)
df3.show()

#df1.groupBy("status").agg(countDistinct(col("idade"))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----+--------+------+
# idade|    nome|status|
# +-----+--------+------+
#    33|   Marco|  true|
#    33| Antonio|  true|
#    33| Pereira|  true|
#    30|  Helena|  true|
#    35|Fernando|  true|
#    28|  Carlos|  true|
#    26|    Lisa|  true|
#    75| Candido| false|
#    62|   Vasco|  true|
# +-----+--------+------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+----------+-------+
# PaisOrigem|   nome|
# +----------+-------+
#     Brasil|  Marco|
#     Brasil| Helena|
#     Brasil|Gabriel|
#   Portugal|  Vasco|
#    Marocco|  Medhi|
# +----------+-------+
#
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+-----+------+------+----------+------+
# idade|  nome|status|PaisOrigem|  nome|
# +-----+------+------+----------+------+
#    30|Helena|  true|    Brasil|Helena|
#    33| Marco|  true|    Brasil| Marco|
#    62| Vasco|  true|  Portugal| Vasco|
# +-----+------+------+----------+------+
#
# </div>

# %%
# Path - RDD
path_rdd = "/FileStore/tables/arquivo_rdd.txt"
rdd = sc.textFile(path_rdd)
df_pre = spark.read.text(path_rdd)

# %%
from pyspark.sql import functions as f
df_pre
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>DataFrame[value: string]</div>

# %%
x = lambda y : y + 1

# %%
x(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>3</div>

# %%
## para TXT's com header
path_rdd = "/FileStore/tables/arquivo_rdd.txt" # especificar o caminho do Bucket
df_pre = spark.read.text(path_rdd)
posicao = ((0,1),(1,5), (5,8))
header= "nome;tipo;texto"
func = lambda p,name,df : df.withColumn(name, df['value'].substr(p[0], p[1]))
def concatenaCampo(posicao, header, df_): 
  i = 0
  header_ = header.split(";")
  for p in posicao:
    df_ = func(p,header_[i],df_)
    print(header_[i])
    i=i+1
  return df_.drop('value')

# %%
header.split(";")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>['nome', 'tipo', 'texto']</div>

# %%
df_pre.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+--------------------+
#                value|
# +--------------------+
# {\rtf1\ansi\ansic...|
# \cocoatextscaling...|
# {\colortbl;\red25...|
# {\*\expandedcolor...|
# \paperw11900\pape...|
#                    }|
# +--------------------+
#
# </div>

# %%
dd = concatenaCampo(posicao, header, df_pre)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>nome
# tipo
# texto
# </div>

# %%
dd.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>+----+-----+--------+
# nome| tipo|   texto|
# +----+-----+--------+
#    {|{\rtf|f1\ansi\|
#    \|\coco|oatextsc|
#    {|{\col|lortbl;\|
#    {|{\*\e|expanded|
#    \|\pape|erw11900|
#    }|    }|        |
# +----+-----+--------+
#
# </div>
